# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
#!git reset --hard fbe67e465375231474a2ad80a4389efc77ecff99
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)

import torch
import glob

from IPython.display import Image, display
from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# %cd /content/yolov5/
# !python detect.py --weights /content/model.pt  --img 10 --data /content/data.yaml --conf 0.3 --source /content/test
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5/yolov5
# Setup complete. Using torch 1.13.1+cu116 CPU
# /content/yolov5
# detect: weights=['/content/model.pt'], source=/content/test, data=/content/data.yaml, imgsz=[10, 10], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-82-gcec1b9b Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# WARNING ⚠️ --img-size [10, 10] must be multiple of max stride 32, updating to [32, 32]
# image 1/16 /content/test/1.jpg: 32x32 1 Cartoon, 66.3ms
# image 2/16 /content/test/10.jpg: 32x32 1 Cartoon, 67.8ms
# image 3/16 /content/test/11.jpg: 32x32 1 Cartoon, 67.3ms
# image 4/16 /content/test/12.jpg: 32x32 1 Cartoon, 72.7ms
# image 5/16 /content/test/13.jpg: 32x32 (no detections), 65.0ms
# image 6/16 /content/test/14.jpg: 32x32 (no detections), 67.2ms
# image 7/16 /content/test/15.jpg: 32x32 (no detections), 67.1ms
# image 8/16 /content/test/16.jpg: 32x32 (no detections), 65.7ms
# image 9/16 /content/test/2.jpg: 32x32 1 Cartoon, 65.2ms
# image 10/16 /content/test/3.jpg: 32x32 1 Cartoon, 66.5ms
# image 11/16 /content/test/4.jpg: 32x32 1 Cartoon, 66.3ms
# image 12/16 /content/test/5.jpg: 32x32 1 Cartoon, 81.1ms
# image 13/16 /content/test/6.jpg: 32x32 1 Cartoon, 77.7ms
# image 14/16 /content/test/7.jpg: 32x32 1 Cartoon, 69.4ms
# image 15/16 /content/test/8.jpg: 32x32 1 Cartoon, 67.7ms
# image 16/16 /content/test/9.jpg: 32x32 1 Cartoon, 65.5ms
# Speed: 0.2ms pre-process, 68.7ms inference, 0.6ms NMS per image at shape (1, 3, 32, 32)
# Results saved to runs/detect/exp5

# %%
for imageName in glob.glob('/content/yolov5/runs/detect/exp5/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
